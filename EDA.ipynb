# %% [markdown]
# ##### This is a Basic Data cleaning and exploration of MyAnimelist Data

# %%
#importing python libraries

import numpy as np
import pandas as pd

# %%
#importing the data as a csv file
df=pd.read_csv('anime.csv')

# %%
#This gives the shape of the matrix used
df.shape
#this for the size
#df.size
# Out:
# (24985, 19)

# %%
#information about the columns and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24985 entries, 0 to 24984
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anime_id       24985 non-null  int64
#  1   title          24985 non-null  object
#  2   type           24927 non-null  object
#  3   score          16050 non-null  float64
#  4   scored_by      24985 non-null  int64
#  5   status         24985 non-null  object
#  6   episodes       24438 non-null  float64
#  7   source         21424 non-null  object
#  8   members        24985 non-null  int64
#  9   favorites      24985 non-null  int64
#  10  rating         24405 non-null  object
#  11  approved       24985 non-null  bool
#  12  start_year     20301 non-null  float64
#  13  start_season   20301 non-null  object
#  14  broadcast_day  3450 non-null   object
#  15  genres         24985 non-null  object
#  16  themes         24985 non-null  object
# ...

# %%
df.head(10)
# Out:
#    anime_id                                 title   type  score  scored_by  \
# 0      5114      Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061                Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524    Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                           Steins;Gate     tv   9.07    1348232
# 4     28851                        Koe no Katachi  movie   8.94    1540277
# 5     32281                        Kimi no Na wa.  movie   8.84    1825476
# 6      2904    Code Geass: Hangyaku no Lelouch R2     tv   8.91    1154270
# 7     40028  Shingeki no Kyojin: The Final Season     tv   8.80    1237778
# 8       199         Sen to Chihiro no Kamikakushi  movie   8.78    1246643
# 9      1575       Code Geass: Hangyaku no Lelouch     tv   8.70    1353753
#
#             status  episodes        source  members  favorites rating  \
# 0  finished_airing      64.0         manga  3206028     219036      r
# ...

# %%
df.value_counts("type")
# Out:
# type
# tv         7632
# movie      4389
# ova        4072
# ona        3523
# music      2772
# special    2539
# dtype: int64

# %%
df.replace(['ona','ova'], 'tv',inplace=True)

# %%
df.value_counts('type')
# Out:
# type
# tv         15227
# movie       4389
# music       2772
# special     2539
# dtype: int64

# %%
df.replace(['music','special'],np.nan,inplace=True)

# %%
df.value_counts('type')
# Out:
# type
# tv       15227
# movie     4389
# dtype: int64

# %%
df.shape
# Out:
# (24985, 19)

# %%
#This must drop all the rows from the data frame having null values in the type column
df.dropna(axis='index',how='all',subset=['type'],inplace=True)

# %%
df.value_counts('type')
# Out:
# type
# tv       15227
# movie     4389
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19616 entries, 0 to 24982
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anime_id       19616 non-null  int64
#  1   title          19616 non-null  object
#  2   type           19616 non-null  object
#  3   score          19616 non-null  float64
#  4   scored_by      19616 non-null  int64
#  5   status         19616 non-null  object
#  6   episodes       19144 non-null  float64
#  7   source         16540 non-null  object
#  8   members        19616 non-null  int64
#  9   favorites      19616 non-null  int64
#  10  rating         19103 non-null  object
#  11  approved       19616 non-null  bool
#  12  start_year     15299 non-null  float64
#  13  start_season   15299 non-null  object
#  14  broadcast_day  3449 non-null   object
#  15  genres         19616 non-null  object
#  16  themes         19616 non-null  object
# ...

# %%
df['score'].fillna(0.0,inplace=True)
df['episodes'].fillna(0.0,inplace=True)

# %%
df[['score','episodes']].median()
# Out:
# score       5.74
# episodes    4.00
# dtype: float64

# %%
df['demographics'].str.contains("Shounen").value_counts()
# Out:
# False    18085
# True      1531
# Name: demographics, dtype: int64

# %%
#this is new line

# %%
#This gave me 2 groups actually dataframes which are divided based on the column data tv and movie
#One contains data related to only tv in type columns andd other with movie
tv=df.groupby(['type'])
movie=df.groupby(['type'])

# %%
tv.get_group('tv')
# Out:
#        anime_id                               title type  score  scored_by  \
# 0          5114    Fullmetal Alchemist: Brotherhood   tv   9.10    2037075
# 1         11061              Hunter x Hunter (2011)   tv   9.04    1671587
# 2         38524  Shingeki no Kyojin Season 3 Part 2   tv   9.05    1491491
# 3          9253                         Steins;Gate   tv   9.07    1348232
# 6          2904  Code Geass: Hangyaku no Lelouch R2   tv   8.91    1154270
# ...         ...                                 ...  ...    ...        ...
# 24962     56058    Buffett Shenmi Julebu 2nd Season   tv   0.00          8
# 24967     55317                        Huan Bing Ji   tv   0.00         16
# 24971     55981                       Xia Chong Guo   tv   0.00         10
# 24973     54876                          Ugoku Ehon   tv   0.00          8
# 24982     56107                Kaijuu Sekai Seifuku   tv   0.00          2
#
# ...
